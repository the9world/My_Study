# %% [markdown]
# 웹대시보드(데이터분석 출력값 웹페이지용) :https://streamlit.io/
# GitHubDeskTop: GitHub -> Open With GitHub Desktop -> 설치 및 실행 ->
# Repositories select -> Clone(?)
#
# ![](attachment:image.png)
# open in visual studio code : 클론한 리포지토리를 vscode로 실행
# (base) command prompt 이거 뜨면 성공
# 뷰-모양-가로막대 버전 클릭 > (base)버전 클릭
#
# 가상환경 셋팅
# \$ python --version--  버전확인
# \$ conda create -n app_dash python=3.9 openssl numpy scipy matplotlib ipython scikit-learn pandas pillow jupyter seaborn
# (\$ 빼야함 터미널에 쓰는 기호)
# ex) $ python --version--
# \$conda create -n 가상환경이름 python=3.9 openssl numpy scipy matplotlib ipython scikit-learn pandas pillow jupyter seaborn
#
#  conda activate app_dash  (가상환경 접근)
#  conda deactivate  (가상환경 나가기)
#  pip install streamlit (설치)
# conda env list (설치된거 확인???)
#
# 웹브라우저에 뭔가 표현하고 싶으면
# st.title("글"), st.text("글")
# 무언가를 웹에 표현할때 쓰는게 streamlit
#
# http://localhost:8501/
# 프로토콜://도메인:port(포트번호)

# %% [markdown]
# 1.문법 (입력하면 무언가 출력하는 것)
# 2.자동차 가격 예측: data -> jupyter notebook -> 기획 등등

# %%
def n_plus_1 (n) :
    result = n + 1
n_plus_1(3)   # result가 함수 내에 있기 때문에 출력되지 않음
# print(result) # 출력 하려면 함수 안에서 해야함.
# 파라미터(n)도 변수다

# %% [markdown]
# ---memory---
# ---n_plus_1 함수 영역---
# n : 3 -> result = n(3) + 1 -> result: 4
# ---함수 밖---
# print(result) 함수 내에 변수는 호출되지 않음

# %%
result = 10
n_plus_1(3)
def n_plus_1(n):
    result= n+1
print(result) # error

result = 10

def n_plus_1(n):
    result= n+1
n_plus_1(3)
print(result) # 10 # 함수 내에 값은 4지만 함수호출이 아니라서
# Out:
# 10
# 10

# %% [markdown]
# ---memory---
# result:10
# ---n_plus_1 함수 영역---
# n: 3
# result: 4
# ---함수끝---
# print(result) = 10가 출력됨

# %%
result = 10
def n_plus_1(n):
    result= n+1
result=n_plus_1(3)
print(result) # 10 출력
# result가 받은 return값이 없음. 함수만 실행했을 뿐?
# Out:
# None

# %%
result = 10
def n_plus_1(n):
    result= n+1
    return result # 바로 위 계산한 result를 n_plus_1에 보낸다
result=n_plus_1(3)
print(result) # 정상적으로 4가 출력
# Out:
# 4
