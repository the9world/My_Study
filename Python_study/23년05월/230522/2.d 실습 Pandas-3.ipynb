# %% [markdown]
# winemag-data-130k-v2.csv 파일을 reviews 로 읽는다.

# %%
import numpy as np
import pandas as pd # pandas 레퍼런스(설명서) 보기 # unnamed:0 없애고 저장하기
reviews= pd.read_csv("https://raw.githubusercontent.com/the9world/My_Study/main/data/winemag-data.csv", index_col=0)
reviews
# Out:
#          country                                        description
# 0          Italy  Aromas include tropical fruit, broom, brimston...  \
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price
# 0                                 Vulkà Bianco      87    NaN  \
# ...

# %% [markdown]
# 리뷰 데이터프레임에서 points 컬럼의  median 값은?

# %%
reviews["points"].median()
# Out:
# 88.0

# %% [markdown]
# 나라를 중복되지 않도록 가져와서 countries 변수에 저장하고, 화면에 출력하시오.

# %%
reviews["country"]
# Out:
# 0            Italy
# 1         Portugal
# 2               US
# 3               US
# 4               US
#             ...
# 129966     Germany
# 129967          US
# 129968      France
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: object

# %%
reviews["country"].unique()
# Out:
# array(['Italy', 'Portugal', 'US', 'Spain', 'France', 'Germany',
#        'Argentina', 'Chile', 'Australia', 'Austria', 'South Africa',
#        'New Zealand', 'Israel', 'Hungary', 'Greece', 'Romania', 'Mexico',
#        'Canada', nan, 'Turkey', 'Czech Republic', 'Slovenia',
#        'Luxembourg', 'Croatia', 'Georgia', 'Uruguay', 'England',
#        'Lebanon', 'Serbia', 'Brazil', 'Moldova', 'Morocco', 'Peru',
#        'India', 'Bulgaria', 'Cyprus', 'Armenia', 'Switzerland',
#        'Bosnia and Herzegovina', 'Ukraine', 'Slovakia', 'Macedonia',
#        'China', 'Egypt'], dtype=object)

# %%
countries= reviews["country"].unique()
countries # 출력 된 것은 numpy array
# Out:
# array(['Italy', 'Portugal', 'US', 'Spain', 'France', 'Germany',
#        'Argentina', 'Chile', 'Australia', 'Austria', 'South Africa',
#        'New Zealand', 'Israel', 'Hungary', 'Greece', 'Romania', 'Mexico',
#        'Canada', nan, 'Turkey', 'Czech Republic', 'Slovenia',
#        'Luxembourg', 'Croatia', 'Georgia', 'Uruguay', 'England',
#        'Lebanon', 'Serbia', 'Brazil', 'Moldova', 'Morocco', 'Peru',
#        'India', 'Bulgaria', 'Cyprus', 'Armenia', 'Switzerland',
#        'Bosnia and Herzegovina', 'Ukraine', 'Slovakia', 'Macedonia',
#        'China', 'Egypt'], dtype=object)

# %% [markdown]
# 각 국가별로는 몇개의 리뷰가 있는지, 각국가별 리뷰수를 구하시오.

# %%
reviews["country"]
# Out:
# 0            Italy
# 1         Portugal
# 2               US
# 3               US
# 4               US
#             ...
# 129966     Germany
# 129967          US
# 129968      France
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: object

# %%
reviews.groupby("country")["country"].count() # col 알파벳 순 A-Z
# Out:
# country
# Argentina                  3800
# Armenia                       2
# Australia                  2329
# Austria                    3345
# Bosnia and Herzegovina        2
# Brazil                       52
# Bulgaria                    141
# Canada                      257
# Chile                      4472
# China                         1
# Croatia                      73
# Cyprus                       11
# Czech Republic               12
# Egypt                         1
# England                      74
# France                    22093
# Georgia                      86
# Germany                    2165
# Greece                      466
# Hungary                     146
# India                         9
# Israel                      505
# Italy                     19540
# Lebanon                      35
# Luxembourg                    6
# Macedonia                    12
# Mexico                       70
# Moldova                      59
# Morocco                      28
# ...

# %%
reviews.groupby("country")["country"].count().sort_values() # 기본 값은 True : 오름차순 : 작은수부터 -> 큰수
# Out:
# country
# China                         1
# Slovakia                      1
# Egypt                         1
# Armenia                       2
# Bosnia and Herzegovina        2
# Luxembourg                    6
# Switzerland                   7
# India                         9
# Cyprus                       11
# Czech Republic               12
# Serbia                       12
# Macedonia                    12
# Ukraine                      14
# Peru                         16
# Morocco                      28
# Lebanon                      35
# Brazil                       52
# Moldova                      59
# Mexico                       70
# Croatia                      73
# England                      74
# Georgia                      86
# Slovenia                     87
# Turkey                       90
# Uruguay                     109
# Romania                     120
# Bulgaria                    141
# Hungary                     146
# Canada                      257
# ...

# %%
reviews.groupby("country")["country"].count().sort_values(ascending=False) # False : 내림차순 : 큰수부터 -> 작은수
# Out:
# country
# US                        54504
# France                    22093
# Italy                     19540
# Spain                      6645
# Portugal                   5691
# Chile                      4472
# Argentina                  3800
# Austria                    3345
# Australia                  2329
# Germany                    2165
# New Zealand                1419
# South Africa               1401
# Israel                      505
# Greece                      466
# Canada                      257
# Hungary                     146
# Bulgaria                    141
# Romania                     120
# Uruguay                     109
# Turkey                       90
# Slovenia                     87
# Georgia                      86
# England                      74
# Croatia                      73
# Mexico                       70
# Moldova                      59
# Brazil                       52
# Lebanon                      35
# Morocco                      28
# ...

# %%
reviews["country"].value_counts() # 기본 값: 내림차순,   ascending=False : 오름차순
# Out:
# US                        54504
# France                    22093
# Italy                     19540
# Spain                      6645
# Portugal                   5691
# Chile                      4472
# Argentina                  3800
# Austria                    3345
# Australia                  2329
# Germany                    2165
# New Zealand                1419
# South Africa               1401
# Israel                      505
# Greece                      466
# Canada                      257
# Hungary                     146
# Bulgaria                    141
# Romania                     120
# Uruguay                     109
# Turkey                       90
# Slovenia                     87
# Georgia                      86
# England                      74
# Croatia                      73
# Mexico                       70
# Moldova                      59
# Brazil                       52
# Lebanon                      35
# Morocco                      28
# ...

# %%
# reviews.sort_values(by='col3',ignore_index=True)) 인덱스로 하는거 /////다시 알아봅////

# %% [markdown]
# 리뷰 데이터프레임의 price 컬럼 값에서, price의 평균값을 뺀 값을, centered_price 라고 저장하시오.

# %%
# reviews = reviews.dropna(subset=['price']) # price 컬럼에 결측치 제거 /// 결측치 제거 안해도 평균 구해짐

# %%
reviews.describe()
# Out:
#               points          price
# count  129971.000000  120975.000000
# mean       88.447138      35.363389
# std         3.039730      41.022218
# min        80.000000       4.000000
# 25%        86.000000      17.000000
# 50%        88.000000      25.000000
# 75%        91.000000      42.000000
# max       100.000000    3300.000000

# %%
reviews["price"].describe()
# Out:
# count    120975.000000
# mean         35.363389
# std          41.022218
# min           4.000000
# 25%          17.000000
# 50%          25.000000
# 75%          42.000000
# max        3300.000000
# Name: price, dtype: float64

# %%
reviews["price"].mean() # 결측치 제거 안해도 평균 구해짐
# Out:
# 35.363389129985535

# %%
centered_price = reviews["price"].mean()
centered_price
# Out:
# 35.363389129985535

# %% [markdown]
# 나는 경제적이므로, 가격대비 포인트가 가장 큰 와인을 사려한다. 해당 와인의 title은?

# %%
# colum 만드는게 데이터 가공
reviews["가성비"]= reviews["points"] / reviews["price"] # 포인트 / 가격이 가성비
reviews.sort_values("가성비", ascending=False) # 가성비 높은 것 부터 나열
# Out:
#          country                                        description  \
# 64590         US  There's a lot going on in this Merlot, which i...
# 126096   Romania  Notes of sun-dried hay and green flower highli...
# 20484         US  Fruity, soft and rather sweet, this wine smell...
# 1987       Spain  Berry and cherry aromas are surprisingly sturd...
# 110255        US  A good everyday Merlot, dry and rich in tannin...
# ...          ...                                                ...
# 129844     Italy  Doga delle Clavule is a neutral, mineral-drive...
# 129860  Portugal  This rich wine has a firm structure as well as...
# 129863  Portugal  This mature wine that has 50% Touriga Nacional...
# 129893     Italy  Aromas of passion fruit, hay and a vegetal not...
# 129964    France  Initially quite muted, this wine slowly develo...
#
#                          designation  points  price         province  \
# 64590                            NaN      86    4.0       California
# ...

# %% [markdown]
# 사람들이 어떤와인을 더 많이 거론했는지 보려한다.
#
# "tropical" 이 들어있는 리뷰의 갯수를 세고, "fruity" 라고 들어있는 리뷰의 갯수를 세어서
#
# 판다스 시리즈로 descriptor_counts 변수로 만들어 보자.

# %% [markdown]
# 깃허브의 데이터분석 항목 참고 (판다스에서 제공하는 다양한 함수들 )
# 데이터프레임의 apply 함수도 고려

# %%
reviews["description"] # 출력 값은 시리즈
# Out:
# 0         Aromas include tropical fruit, broom, brimston...
# 1         This is ripe and fruity, a wine that is smooth...
# 2         Tart and snappy, the flavors of lime flesh and...
# 3         Pineapple rind, lemon pith and orange blossom ...
# 4         Much like the regular bottling from 2012, this...
#                                 ...
# 129966    Notes of honeysuckle and cantaloupe sweeten th...
# 129967    Citation is given as much as a decade of bottl...
# 129968    Well-drained gravel soil gives this wine its c...
# 129969    A dry style of Pinot Gris, this is crisp with ...
# 129970    Big, rich and off-dry, this is powered by inte...
# Name: description, Length: 129971, dtype: object

# %%
reviews["description"].str.contains("tropical").sum()
# true(1) false(0)을 반환해서 sum쓰면 그 값을 합쳐서 갯수를 셀수 있음
# Out:
# 3607

# %%
reviews["description"].str.contains("fruity").sum()
# Out:
# 9090

# %% [markdown]
# 2번. 방법 apply 사용

# %%
# apply("함수") 파라미터는 "함수" 넣는것 ("def "함수"():"")
def is_tropical(sentence):
  if "tropical" in sentence :
    return True
  else :
    return False

# %%
reviews["description"].apply(is_tropical).sum()
# apply("함수") 파라미터는 "함수" 넣는것 ("def "함수"():"")
# Out:
# 3607

# %%
def is_fruity(sentence):
  if "fruity" in sentence :
    return True
  else :
    return False

# %%
reviews["description"].apply(is_fruity).sum()
# Out:
# 9090

# %%
len(reviews[reviews['description'].str.contains('tropical')])
reviews10=reviews[reviews['description'].str.contains('tropical')]
reviews10
# Out:
#              country                                        description  \
# 0              Italy  Aromas include tropical fruit, broom, brimston...
# 34                US  This shows a tart, green gooseberry flavor tha...
# 43                US  The clean, brisk mouthfeel gives this slightly...
# 91                US  This wine has a touch of perceptible sweetness...
# 116               US  The distinctive nose on this bottling is tight...
# ...              ...                                                ...
# 129779            US  Exceptionally ripe, this has notes of tropical...
# 129783            US  With balance and grip, this lightly effervesce...
# 129883  South Africa  A tropical tone of grilled pineapple adds brea...
# 129916       Austria  Spicy, vanilla new wood aromas dominate this w...
# 129922       Austria  Herbs, spices and green fruit aromas show the ...
#
#                   designation  points  price           province  \
# ...

# %%
# len(reviews10[reviews10['description'].str.contains('fruity')])
# descriptor_counts1 = reviews10[reviews10['description'].str.contains('fruity')]
# descriptor_counts = descriptor_counts1.loc[:,"description"]
# descriptor_counts

# %%
counts_1 = ['tropical', 'fruity']
reviews[reviews['description'].map(lambda x: all(string in x for string in counts_1))]

# 추가) 위 코드를 실행하면 오류가 날 수있는데요. 오류가 나는 경우는 아래와 같이 engine 인자에 'python'을 넣어주세요. 
# df.query('주소.str.contains("서울")',engine='python')
# https://zephyrus1111.tistory.com/46
# https://csshark.tistory.com/63
# Out:
#          country                                        description  \
# 668           US  While dry in style, this lithe, delicately fra...
# 967        Chile  Light and tropical, with buttercup aromas and ...
# 1700    Portugal  Rounded but also fruity, this soft wine is per...
# 2565     Austria  There is a high-toned aspect to the otherwise ...
# 2961          US  Lots to like in this dry, fruity Chardonnay. I...
# ...          ...                                                ...
# 126441    France  This is a ripe, delicately tropical and fruity...
# 126580        US  While exuberantly fruity, almost tropical on t...
# 126928    France  In this soft, ripe wine, rounded tropical frui...
# 128611    France  Brightly fruity, this blend with 85% Sauvignon...
# 128728        US  Boundary Breaks is an exciting new project fro...
#
#              designation  points  price           province  \
# 668         Virgin Berry      90   26.0           New York
# ...

# %% [markdown]
# 별점 시스템을 만들려고 한다. 따라서 별점에 대한 데이터가 필요하다.
#
# 별점은 1,2,3 즉 3개로 만들것이다.
#
# 포인트가 95점 이상이면 3점, 85점 이상이면 2점, 나머지는 1점으로 할 것이다.
#
# 리뷰데이터를 통해 각 데이터의 별점을 구하시오.

# %%
# def star_point(self):
#   for i in reviews["points"]:
#     if i >= 95:
#       return 3
#     elif i >= 85 and i < 95 :
#       return 2
#     else:
#       return 1
# reviews["star"]= reviews["points"].apply(star_point)
# print((reviews["star"] == 3).sum())
# reviews
# 내가 한건데 확실히 된건지 모르겠음

# %%
def get_star(point):
  if point >= 95:
    return 3
  elif point >= 85:
    return 2
  else:
    return 1
reviews["star"] = reviews["points"].apply(get_star)
print((reviews["star"] == 3).sum())
reviews
# Out:
# 2416
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# ...

# %% [markdown]
# 리뷰의 region_2 컬럼에 데이터가 비어있는 경우에는, 'Unknown'으로 셋팅하자.

# %%
reviews["region_2"].replace(np.NaN, "Unknown", inplace=True)
reviews
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# ...

# %%
reviews["region_2"]= reviews["region_2"].fillna("Unknown")
reviews
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# ...

# %% [markdown]
# #### 각 포인트 별로, 몇개의 리뷰가 있는가?
# #### 예를 들어, 95점은 4개, 94점은 10개 등등.. 알고 싶은 경우다.

# %%
reviews["points"].value_counts().sort_values()

# %%
reviews.groupby("points")["points"].count() # 이거 좀 답이 다름 이유 모름

# %%
# 강사님 풀이
reviews['points'].value_counts()

# %% [markdown]
# #### 가장 점수가 높은 와인은?

# %%
reviews['points']= reviews["points"].sort_values()
reviews

# %%
# 풀이
reviews['points']==reviews['points'].max()

# %%
reviews.loc[reviews['points'] == reviews['points'].max() , ]

# %% [markdown]
# #### 점수는 높고 가격은 싼 와인 순으로 보여주시오.

# %%
po1=reviews[(reviews["points"]==100)]
po1=po1.sort_values("price")
po1
# Out:
#           country                                        description  \
# 123545         US  Initially a rather subdued Frog; as if it has ...
# 113929         US  In 2005 Charles Smith introduced three high-en...
# 58352      France  This is a magnificently solid wine, initially ...
# 45798          US  Tasted in a flight of great and famous Napa wi...
# 7335        Italy  Thick as molasses and dark as caramelized brow...
# 89728      France  This latest incarnation of the famous brand is...
# 36528      France  This is a fabulous wine from the greatest Cham...
# 111754      Italy  It takes only a few moments before you appreci...
# 345     Australia  This wine contains some material over 100 year...
# 111756     France  A hugely powerful wine, full of dark, brooding...
# 42197    Portugal  This is the latest release of what has long be...
# 118058         US  This wine dazzles with perfection. Sourced fro...
# 39286       Italy  A perfect wine from a classic vintage, the 200...
# ...

# %%
# 풀이
reviews.sort_values(['points', 'price']) # 여러개 하려면 리스트로 만들어서 해야함
reviews.sort_values(['points', 'price'], ascending=[False, True]) # 이것도 마찬가지 리스트로
# Out:
#          country                                        description  \
# 113929        US  In 2005 Charles Smith introduced three high-en...
# 123545        US  Initially a rather subdued Frog; as if it has ...
# 58352     France  This is a magnificently solid wine, initially ...
# 45798         US  Tasted in a flight of great and famous Napa wi...
# 7335       Italy  Thick as molasses and dark as caramelized brow...
# ...          ...                                                ...
# 122417        US  There's little going on in this wine beyond su...
# 28569         US  Smells and tastes like caramel and stewed cher...
# 103989        US  This suffers from major problems. It has all t...
# 117025  Portugal  A curious sauerkraut perfume leads to a hard e...
# 123541     Italy  This Valpolicella blend opens with an aged, br...
#
#                  designation  points  price    province  \
# 113929            Royal City     100   80.0  Washington
# ...

# %% [markdown]
# #### 포인트 별로, 가격의 최소값을 구해본다.
# #### 이것을 구하면, 100점짜리 와인을 먹으려면, 최소한 얼마가 있어야 하는지 파악이 가능함.

# %%
reviews.groupby("points")['price'].min() # groupby로 서로 묶고 그에 대한 최소 값을 구한다.
reviews.groupby("points")['price'].max() # groupby로 서로 묶고 그에 대한 최대 값을 구한다.
# 둘다 보려면 : .agg([]) : 함수를 여러개 쓸 수 있게 하는 numpy 함수
reviews.groupby("points")['price'].agg([np.min, np.max]).sort_index(ascending=False)
# Out:
#         amin    amax
# points
# 100     80.0  1500.0
# 99      44.0   850.0
# 98      50.0  1900.0
# 97      35.0  2000.0
# 96      20.0  2500.0
# 95      20.0   973.0
# 94      13.0  1125.0
# 93      12.0   770.0
# 92      11.0   750.0
# 91       7.0  2013.0
# 90       8.0   510.0
# 89       7.0   500.0
# 88       6.0  3300.0
# 87       5.0   800.0
# 86       4.0   170.0
# 85       4.0   320.0
# 84       4.0   225.0
# 83       4.0   225.0
# 82       4.0   150.0
# 81       5.0   130.0
# 80       5.0    69.0
