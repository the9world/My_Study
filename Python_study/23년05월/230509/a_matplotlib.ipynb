# %%
# !sudo apt-get install -y fonts-nanum
# Out:
# 'sudo'��(��) ���� �Ǵ� �ܺ� ����, ������ �� �ִ� ���α׷�, �Ǵ�
# ��ġ ������ �ƴմϴ�.

# %% [markdown]
# ![qnsfb dPcmr.png](<attachment:qnsfb dPcmr.png>)

# %% [markdown]
# 1. 데이터 세트 분리 : 데이터를 학습 데이터와 테스트 데이터로 분리
# 2. 모델 학습 : 학습 데이터를 기반으로 ML 알고리즘을 적용해 모델을 학습
# 3. 예측 수행 : 학습된 ML 모델을 이용해 테스트 데이터의 분류(즉, 붓꽃 종류)를 예측
# 4. 평가 : 이렇게 예측된 결과 값과 테스트 데이터의 실제 결과 값을 비교해 ML 모델 성능을 평가

# %%
import matplotlib.pyplot as plt
plt.rc('font', family='Arial')

# %%
import matplotlib.pyplot as plt

fig,axs = plt.subplots(1,3, figsize=(9,3)) #가로 : 9cm / 세로 : 3cm

axs[1].set_xticks([0,2,4,6])
axs[1].set_yticks([0,5,10])

axs[2].set_xticks([0,1,2,3,4]) # 이건 내가 넣은거 지워야할지도
axs[2].set_xticklabels(['A','B','C','D','E'])
axs[2].set_yticks([0,1,2])
axs[2].set_yticklabels(['a','b','c'])

plt.show()

# %%
import matplotlib.pyplot as plt

fig,axs = plt.subplots(1,3, figsize=(9,3)) #9cm / 3cm

fig,axs = plt.subplots(1,3, figsize=(9,3)) #9cm / 3cm
