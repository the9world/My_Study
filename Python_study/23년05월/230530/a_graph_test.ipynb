# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('grayscale')
plt.plot([1, 2, 3, 4], [4, 6, 2, 7])
plt.show()
# plt.style.available # 그래프 디자인 종류 보기
# 'Solarize_Light2', # 여기서 부터 아래까지 그래프 디자인
# '_classic_test_patch',
# '_mpl-gallery',
# '_mpl-gallery-nogrid',
# 'bmh',
# 'classic',
# 'dark_background',
# 'fast',
# 'fivethirtyeight',
# 'ggplot',
# 'grayscale',
# 'seaborn-v0_8',
# 'seaborn-v0_8-bright',
# 'seaborn-v0_8-colorblind',
# 'seaborn-v0_8-dark',
# 'seaborn-v0_8-dark-palette',
# 'seaborn-v0_8-darkgrid',
# 'seaborn-v0_8-deep',
# 'seaborn-v0_8-muted',
# 'seaborn-v0_8-notebook',
# 'seaborn-v0_8-paper',
# 'seaborn-v0_8-pastel',
# 'seaborn-v0_8-poster',
# 'seaborn-v0_8-talk',
# 'seaborn-v0_8-ticks',
# 'seaborn-v0_8-white',
# 'seaborn-v0_8-whitegrid',
# 'tableau-colorblind10'

# 그래프 종류 : barh, stem, pie, hist, scatter, imshow, contour, surface
# https://wikidocs.net/141547
# https://datascienceschool.net/01%20python/05.02%20%EB%A7%B7%ED%94%8C%EB%A1%AF%EB%A6%AC%EB%B8%8C%EC%9D%98%20%EC%97%AC%EB%9F%AC%EA%B0%80%EC%A7%80%20%ED%94%8C%EB%A1%AF.html

# %%
import pandas as pd
import random
series1 = pd.read_csv("C:/Users/The9/Documents/My_Study/data/50_Startups.csv", encoding="UTF-8")
height = series1["R&D Spend"]
x_values = range(len(height))
plt.style.use("ggplot")
plt.bar(x_values, height)
# Out:
# <BarContainer object of 50 artists>

# %%
plt.style.use("grayscale")
plt.bar(range(len(series1['Administration'])),series1['Administration'])
# Out:
# <BarContainer object of 50 artists>
